# %% [markdown]
# # Phase 0 Feasibility Pilot
# This notebook calls the pilot discovery script without modifying primary datasets.

# %%
# !pip install pyyaml -q

# %%
import sys
import os

# Add src to path
sys.path.append(os.path.abspath('..'))

from scripts.run_feasibility_pilot import run
run()

# %%
import pandas as pd
import json
import os

# Preview the exported pilot candidates
output_file = '../outputs/pilot_curated_examples.jsonl'
if os.path.exists(output_file):
    with open(output_file, 'r') as f:
        data = [json.loads(line) for line in f]
    
    if data:
        df = pd.DataFrame(data)
        display(df[['example_id', 'source', 'labels']].head())
    else:
        print('No candidates found yet.')
else:
    print('OutputFile missing. Run the script first.')
